# %% [markdown]
# <a href="https://colab.research.google.com/github/joanby/python-ml-course/blob/master/notebooks/T4%20-%202%20-%20Linear%20Regression%20-%20Regresión%20lineal%20con%20statsmodel-Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clonamos el repositorio para obtener los dataSet

# %%
# !git clone https://github.com/DavidArroyoTorres/python-ml-course/
# Out:
# Cloning into 'python-ml-course'...
# remote: Enumerating objects: 17888, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 17888 (delta 85), reused 5 (delta 5), pack-reused 17758 (from 2)
# Receiving objects: 100% (17888/17888), 531.66 MiB | 16.02 MiB/s, done.
# Resolving deltas: 100% (425/425), done.
# Updating files: 100% (16940/16940), done.

# %% [markdown]
# # Damos acceso a nuestro Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Test it
# !ls '/content/drive/My Drive'

# %%
from google.colab import files # Para manejar los archivos y, por ejemplo, exportar a su navegador
import glob # Para manejar los archivos y, por ejemplo, exportar a su navegador
from google.colab import drive # Montar tu Google drive

# %% [markdown]
# # Regresión lineal simple en Python
# ## El paquete statsmodel para regresión lineal

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/python-ml-course/datasets/ads/Advertising.csv")

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
import statsmodels.formula.api as smf

# %%
lm = smf.ols(formula="Sales~TV", data = data).fit()

# %%
lm.params
# Out:
# Intercept    7.032594
# TV           0.047537
# dtype: float64

# %% [markdown]
# El modelo lineal predictivo sería
# Sales = 7.032594 + 0.047537 * TV

# %%
lm.pvalues
# Out:
# Intercept    1.406300e-35
# TV           1.467390e-42
# dtype: float64

# %%
lm.rsquared
# Out:
# 0.611875050850071

# %%
lm.rsquared_adj
# Out:
# 0.6099148238341623

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Sat, 19 Sep 2020   Prob (F-statistic):           1.47e-42
# Time:                        16:00:18   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %%
sales_pred = lm.predict(pd.DataFrame(data["TV"]))
sales_pred
# Out:
# 0      17.970775
# 1       9.147974
# 2       7.850224
# 3      14.234395
# 4      15.627218
#          ...
# 195     8.848493
# 196    11.510545
# 197    15.446579
# 198    20.513985
# 199    18.065848
# Length: 200, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import plotly.graph_objects as go

# Scatter (tus datos)
fig = go.Figure()

fig.add_trace(go.Scatter3d(
    x=data["Radio"],
    y=data["TV"],
    z=data["Sales"],
    mode='markers',
    marker=dict(
        size=5,
        color=data["Newspaper"],
        colorscale='Viridis',
        opacity=0.8
    ),
    name="Datos"
))

# Crear grid para el plano
x_range = np.linspace(data["Radio"].min(), data["Radio"].max(), 20)
y_range = np.linspace(data["TV"].min(), data["TV"].max(), 20)

X, Y = np.meshgrid(x_range, y_range)

# Ecuación del plano
Z = 2.921100 + 0.187994 * X + 0.045755 * Y

# Añadir plano
fig.add_trace(go.Surface(
    x=X,
    y=Y,
    z=Z,
    opacity=0.5,
    colorscale='Reds',
    showscale=False,
    name="Plano"
))

fig.update_layout(
    scene=dict(
        aspectmode='manual',
        aspectratio=dict(x=1.5, y=10, z=1)
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

fig = px.scatter_3d(
    data,
    x="Radio",
    y="TV",
    z="Sales",
    #color="Newspaper"  # opcional
)

fig.update_layout(
    scene=dict(
        aspectmode='manual',
        aspectratio=dict(x=1.5, y=10, z=1)
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# %matplotlib inline
data.plot(kind = "scatter", x = "Radio", y ="Sales")
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
figure, axs = plt.subplots(2,2, sharey=True, sharex=True)
data.plot(kind="scatter", x="TV", y ="Sales", ax=axs[0][0])
data.plot(kind="scatter", x="Radio", y="Sales", ax=axs[0][1])
data.plot(kind="scatter", x="Newspaper", y ="Sales", ax=axs[1][0])
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
# %matplotlib inline
data.plot(kind = "scatter", x = "TV", y ="Sales")
plt.plot(pd.DataFrame(data["TV"]), sales_pred, c="red", linewidth = 2)

# %%
data["sales_pred"] = 7.032594 + 0.047537*data["TV"]

# %%
data["RSE"] = (data["Sales"]-data["sales_pred"])**2

# %%
SSD = sum(data["RSE"])
SSD
# Out:
# 2102.5305838896525

# %%
RSE = np.sqrt(SSD/(len(data)-2))
RSE
# Out:
# 3.258656369238098

# %%
sales_m = np.mean(data["Sales"])

# %%
sales_m
# Out:
# 14.022500000000003

# %%
error = RSE/sales_m

# %%
error
# Out:
# 0.2323876890168014

# %%
plt.hist((data["Sales"]-data["sales_pred"]))
# Out:
# (array([ 4., 10., 13., 17., 40., 42., 33., 16., 17.,  8.]),
#  array([-8.3860819 , -6.82624404, -5.26640618, -3.70656832, -2.14673046,
#         -0.5868926 ,  0.97294526,  2.53278312,  4.09262098,  5.65245884,
#          7.2122967 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Regresión lineal múltiple en Python
# ## El paquete statsmodel para regresión múltiple
# * Sales ~TV
# * Sales ~Newspaper
# * Sales ~Radio
# * Sales ~TV+Newspaper
# * Sales ~TV+Radio
# * Sales ~Newspaper+Radio
# * Sales ~TV+Newspaper+Radio

# %%
#Añadir el Newspaper al modelo existente
lm2 = smf.ols(formula="Sales~Radio+TV", data = data).fit()

# %%
2.921100+0.187994x+0.045755y

# %%
lm2.params
# Out:
# Intercept    2.921100
# Radio        0.187994
# TV           0.045755
# dtype: float64

# %%
lm2.pvalues
# Out:
# Intercept    3.145860e-22
# TV           5.507584e-44
# Newspaper    2.217084e-05
# dtype: float64

# %% [markdown]
# Sales = 5.774948+0.046901*TV + 0.044219*Newspaper

# %%
lm2.rsquared
# Out:
# 0.6458354938293271

# %%
lm2.rsquared_adj
# Out:
# 0.6422399150864777

# %%
sales_pred = lm2.predict(data[["TV", "Newspaper"]])

# %%
sales_pred
# Out:
# 0      19.626901
# 1       9.856348
# 2       9.646055
# 3      15.467318
# 4      16.837102
#          ...
# 195     8.176802
# 196    10.551220
# 197    14.359467
# 198    22.003458
# 199    17.045429
# Length: 200, dtype: float64

# %%
SSD = sum((data["Sales"]-sales_pred)**2)

# %%
SSD
# Out:
# 1918.5618118968268

# %%
RSE = np.sqrt(SSD/(len(data)-2-1))

# %%
RSE
# Out:
# 3.120719860252885

# %%
error = RSE / sales_m

# %%
error
# Out:
# 0.22255089037282116

# %%
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.646
# Model:                            OLS   Adj. R-squared:                  0.642
# Method:                 Least Squares   F-statistic:                     179.6
# Date:                Sat, 19 Sep 2020   Prob (F-statistic):           3.95e-45
# Time:                        16:00:22   Log-Likelihood:                -509.89
# No. Observations:                 200   AIC:                             1026.
# Df Residuals:                     197   BIC:                             1036.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.7749      0.525     10.993      0.000       4.739       6.811
# ...

# %%
#Añadir la Radio al modelo existente
lm3 = smf.ols(formula="Sales~TV+Radio", data = data).fit()

# %%
lm3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     859.6
# Date:                Sat, 19 Sep 2020   Prob (F-statistic):           4.83e-98
# Time:                        16:00:22   Log-Likelihood:                -386.20
# No. Observations:                 200   AIC:                             778.4
# Df Residuals:                     197   BIC:                             788.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9211      0.294      9.919      0.000       2.340       3.502
# ...

# %%
sales_pred = lm3.predict(data[["TV", "Radio"]])
SSD = sum((data["Sales"]-sales_pred)**2)
RSE = np.sqrt(SSD/(len(data)-2-1))

# %%
RSE
# Out:
# 1.681360912508001

# %%
RSE/sales_m
# Out:
# 0.11990450436855059

# %%
#Añadir la Radio al modelo existente
lm4 = smf.ols(formula="Sales~TV+Radio+Newspaper", data = data).fit()

# %%
lm4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Sat, 19 Sep 2020   Prob (F-statistic):           1.58e-96
# Time:                        16:00:23   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
sales_pred = lm4.predict(data[["TV", "Radio","Newspaper"]])
SSD = sum((data["Sales"]-sales_pred)**2)
RSE = np.sqrt(SSD/(len(data)-3-1))

# %%
RSE
# Out:
# 1.6855103734147443

# %%
RSE/sales_m
# Out:
# 0.1202004188564624

# %% [markdown]
# ## Multicolinealidad
# #### Factor Inflación de la Varianza
# * VIF = 1 : Las variables no están correlacionadas
# * VIF < 5 : Las variables tienen una correlación moderada y se pueden quedar en el modelo
# * VIF >5 : Las variables están altamente correlacionadas y deben desaparecer del modelo.

# %%
# Newspaper ~ TV + Radio -> R^2 VIF = 1/(1-R^2)
lm_n = smf.ols(formula="Newspaper~TV+Radio", data = data).fit()
rsquared_n = lm_n.rsquared
VIF = 1/(1-rsquared_n)
VIF
# Out:
# 1.1451873787239288

# %%
# TV ~ Newspaper + Radio -> R^2 VIF = 1/(1-R^2)
lm_tv = smf.ols(formula="TV~Newspaper+Radio", data=data).fit()
rsquared_tv = lm_tv.rsquared
VIF = 1/(1-rsquared_tv)
VIF
# Out:
# 1.0046107849396502

# %%
# Radio ~ TV + Newspaper -> R^2 VIF = 1/(1-R^2)
lm_r = smf.ols(formula="Radio~Newspaper+TV", data=data).fit()
rsquared_r = lm_r.rsquared
VIF = 1/(1-rsquared_r)
VIF
# Out:
# 1.1449519171055353

# %%
lm3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     859.6
# Date:                Sat, 19 Sep 2020   Prob (F-statistic):           4.83e-98
# Time:                        16:00:23   Log-Likelihood:                -386.20
# No. Observations:                 200   AIC:                             778.4
# Df Residuals:                     197   BIC:                             788.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9211      0.294      9.919      0.000       2.340       3.502
# ...
