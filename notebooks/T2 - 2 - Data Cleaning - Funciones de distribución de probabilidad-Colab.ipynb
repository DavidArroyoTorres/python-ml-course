# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidArroyoTorres/python-ml-course/blob/master/notebooks/T2%20-%202%20-%20Data%20Cleaning%20-%20Funciones%20de%20distribuci%C3%B3n%20de%20probabilidad-Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Funciones de distribución de probabilidades
# ## Distribución Uniforme

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/DavidArroyoTorres/python-ml-course/
# Out:
# Cloning into 'python-ml-course'...
# remote: Enumerating objects: 17836, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 17836 (delta 51), reused 6 (delta 6), pack-reused 17758 (from 2)
# Receiving objects: 100% (17836/17836), 530.92 MiB | 23.44 MiB/s, done.
# Resolving deltas: 100% (391/391), done.
# Updating files: 100% (16940/16940), done.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
a = 1
b = 100
n = 7
data = np.random.uniform(a, b, n)
data
# Out:
# array([27.27559399, 70.10968503, 67.86459486, 38.03092413, 72.14319747,
#        21.86552072, 82.85565016])

# %%
# %matplotlib inline
plt.hist(data,bins=30)
# Out:
# (array([3., 0., 1., 4., 1., 2., 4., 2., 6., 1., 5., 1., 1., 4., 1., 2., 3.,
#         1., 1., 3., 1., 1., 1., 2., 4., 5., 1., 0., 3., 6.]),
#  array([ 5.13642844,  8.27202033, 11.40761223, 14.54320413, 17.67879602,
#         20.81438792, 23.94997981, 27.08557171, 30.22116361, 33.3567555 ,
#         36.4923474 , 39.6279393 , 42.76353119, 45.89912309, 49.03471498,
#         52.17030688, 55.30589878, 58.44149067, 61.57708257, 64.71267447,
#         67.84826636, 70.98385826, 74.11945015, 77.25504205, 80.39063395,
#         83.52622584, 86.66181774, 89.79740964, 92.93300153, 96.06859343,
#         99.20418532]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ## Distribución Normal

# %%
data = np.random.randn(10000)

# %%
x = range(10000)
plt.figure(figsize=(30,15))
plt.plot(x, data)

# %%
# %matplotlib inline
plt.hist(data,bins=100)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   0.,   1.,   1.,   1.,   1.,   5.,
#           3.,   2.,   5.,   6.,   6.,   4.,  10.,  13.,  16.,  14.,  29.,
#          27.,  36.,  47.,  45.,  50.,  60.,  54.,  89.,  92.,  89., 106.,
#         123., 145., 176., 191., 189., 186., 204., 245., 233., 257., 291.,
#         261., 249., 286., 309., 303., 334., 336., 343., 320., 314., 298.,
#         315., 321., 261., 265., 242., 205., 186., 192., 174., 166., 159.,
#         148., 148.,  97., 106.,  95.,  86.,  56.,  59.,  54.,  50.,  39.,
#          35.,  28.,  18.,  28.,  13.,   6.,   9.,   4.,   7.,   4.,   4.,
#           1.,   2.,   4.,   3.,   1.,   0.,   0.,   1.,   0.,   1.,   0.,
#           1.]),
#  array([-3.98511346, -3.90614446, -3.82717547, -3.74820647, -3.66923748,
#         -3.59026848, -3.51129949, -3.43233049, -3.3533615 , -3.2743925 ,
#         -3.19542351, -3.11645451, -3.03748552, -2.95851652, -2.87954753,
#         -2.80057853, -2.72160954, -2.64264054, -2.56367155, -2.48470255,
#         -2.40573356, -2.32676456, -2.24779557, -2.16882657, -2.08985758,
#         -2.01088858, -1.93191959, -1.85295059, -1.7739816 , -1.6950126 ,
#         -1.61604361, -1.53707461, -1.45810562, -1.37913662, -1.30016763,
#         -1.22119863, -1.14222964, -1.06326064, -0.98429165, -0.90532265,
#         -0.82635366, -0.74738466, -0.66841567, -0.58944667, -0.51047768,
#         -0.43150868, -0.35253969, -0.27357069, -0.1946017 , -0.1156327 ,
#         -0.03666371,  0.04230529,  0.12127428,  0.20024328,  0.27921227,
#          0.35818127,  0.43715026,  0.51611926,  0.59508825,  0.67405725,
#          0.75302624,  0.83199524,  0.91096423,  0.98993323,  1.06890222,
#          1.14787122,  1.22684021,  1.30580921,  1.3847782 ,  1.4637472 ,
#          1.54271619,  1.62168519,  1.70065418,  1.77962318,  1.85859217,
#          1.93756117,  2.01653016,  2.09549916,  2.17446816,  2.25343715,
#          2.33240615,  2.41137514,  2.49034414,  2.56931313,  2.64828213,
#          2.72725112,  2.80622012,  2.88518911,  2.96415811,  3.0431271 ,
#          3.1220961 ,  3.20106509,  3.28003409,  3.35900308,  3.43797208,
#          3.51694107,  3.59591007,  3.67487906,  3.75384806,  3.83281705,
#          3.91178605]),
#  <BarContainer object of 100 artists>)

# %%
plt.plot(x,sorted(data))

# %%
mu = 5.5
sd = 2.5
Z_10000 = np.random.randn(10000)
data = mu + sd * Z_10000 # Z = (X - mu) / sd -> N(0,1), X = mu + sd * Z
plt.hist(data)
# Out:
# (array([  10.,   89.,  466., 1766., 2896., 2861., 1414.,  429.,   65.,
#            4.]),
#  array([-4.24623314, -2.2667752 , -0.28731726,  1.69214068,  3.67159862,
#          5.65105656,  7.6305145 ,  9.60997244, 11.58943037, 13.56888831,
#         15.54834625]),
#  <a list of 10 Patch objects>)

# %%
data = np.random.randn(2,4)
data
# Out:
# array([[ 0.00239305,  0.66424699, -0.46608439, -2.06345436],
#        [ 0.10321101,  0.10132709, -0.70695038, -0.87042236]])

# %% [markdown]
# ## La simulación de Monte Carlo

# %% [markdown]
# * Generamos dos números aleatorios uniforme x e y entre 0 y 1 en total 1000 veces.
# * Calcularemos $z = x^2 + y^2$:
#     * Si $z < 1 \rightarrow$ estamos dentro del círculo.
#     * Si $z \geq 1 \rightarrow$ estamos fuera del círculo.
# * Calculamos el número total de veces que están dentro del círculo y lo dividimos entre el número total de intentos para obtener una aproximación de la probabilidad de caer dentro del círculo.
# * Usamos dicha probabilidad para aproximar el valor de π.
# * Repetimos el experimento un número suficiente de veces (por ejemplo 100), para obtener (100) diferentes aproximaciones de π.
# * Calculamos el promedio de los 100 experimentos anteriores para dar un valor final de π.

# %%
def pi_montecarlo(n, n_exp):
    pi_avg = 0
    pi_value_list = []
    for i in range(n_exp):
        value = 0
        x = np.random.uniform(0,1,n).tolist()
        y = np.random.uniform(0,1,n).tolist()
        for j in range(n):
            z = np.sqrt(x[j] * x[j] + y[j] * y[j])
            if z<=1:
                value += 1
        float_value = float(value)
        pi_value = float_value * 4 / n
        pi_value_list.append(pi_value)
        pi_avg += pi_value

    pi = pi_avg/n_exp

    print(pi)
    fig = plt.plot(pi_value_list)
    return (pi, fig)

# %%
pi_montecarlo(10000, 200)
# Out:
# 3.143076000000002
# (3.143076000000002, [<matplotlib.lines.Line2D at 0x7f85134a1ac8>])

# %% [markdown]
# ### Dummy Data Sets

# %%
n = 1000000
data = pd.DataFrame(
    {
        'A' : np.random.randn(n),
        'B' : 1.5 + 2.5 * np.random.randn(n),
        'C' : np.random.uniform(5, 32, n)
    }
)

# %%
data.describe()
# Out:
#                     A               B               C
# count  1000000.000000  1000000.000000  1000000.000000
# mean         0.002164        1.499644       18.508191
# std          0.999902        2.501756        7.794876
# min         -4.614127      -11.344276        5.000005
# 25%         -0.673665       -0.187840       11.749997
# 50%          0.002129        1.502898       18.506363
# 75%          0.678266        3.187172       25.261393
# max          4.553337       13.301662       31.999969

# %%
plt.hist(data["A"])
# Out:
# (array([1.22000e+02, 2.50800e+03, 2.81180e+04, 1.40963e+05, 3.15165e+05,
#         3.24594e+05, 1.52739e+05, 3.25730e+04, 3.09000e+03, 1.28000e+02]),
#  array([-4.61412738, -3.69738095, -2.78063452, -1.86388809, -0.94714166,
#         -0.03039522,  0.88635121,  1.80309764,  2.71984407,  3.6365905 ,
#          4.55333693]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data["B"])
# Out:
# (array([1.20000e+01, 8.29000e+02, 1.39770e+04, 1.01506e+05, 3.00478e+05,
#         3.64624e+05, 1.79885e+05, 3.57100e+04, 2.90300e+03, 7.60000e+01]),
#  array([-11.34427637,  -8.87968257,  -6.41508878,  -3.95049498,
#          -1.48590119,   0.9786926 ,   3.4432864 ,   5.90788019,
#           8.37247399,  10.83706778,  13.30166157]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data["C"])
# Out:
# (array([ 99574., 100661.,  99456.,  99788., 100310.,  99741.,  99869.,
#         100111., 100293., 100197.]),
#  array([ 5.00000455,  7.70000101, 10.39999746, 13.09999392, 15.79999037,
#         18.49998682, 21.19998328, 23.89997973, 26.59997619, 29.29997264,
#         31.99996909]),
#  <a list of 10 Patch objects>)

# %%
data = pd.read_csv("/content/drive/My Drive/Curso Machine Learning con Python/datasets/customer-churn-model/Customer Churn Model.txt")

# %%
data.head()
# Out:
#   State  Account Length  Area Code  ... Intl Charge CustServ Calls  Churn?
# 0    KS             128        415  ...        2.70              1  False.
# 1    OH             107        415  ...        3.70              1  False.
# 2    NJ             137        415  ...        3.29              0  False.
# 3    OH              84        408  ...        1.78              2  False.
# 4    OK              75        415  ...        2.73              3  False.
#
# [5 rows x 21 columns]

# %%
colum_names = data.columns.values.tolist()

# %%
a = len(colum_names)
a
# Out:
# 21

# %%
new_data = pd.DataFrame(
    {
        'Column Name': colum_names,
        'A' : np.random.randn(a),
        'B' : np.random.uniform(0,1,a)
    }, index = range(42, 42 + a)
)

# %%
new_data
# Out:
#        Column Name         A         B
# 42           State  0.009601  0.571675
# 43  Account Length  1.127091  0.203394
# 44       Area Code  1.413309  0.426407
# 45           Phone  1.335081  0.190180
# 46      Int'l Plan -0.828382  0.156801
# 47      VMail Plan  0.608314  0.255236
# 48   VMail Message -1.529998  0.688072
# 49        Day Mins  0.463638  0.638551
# 50       Day Calls -0.419050  0.900912
# 51      Day Charge  0.180764  0.204704
# 52        Eve Mins -0.569117  0.213367
# 53       Eve Calls -1.260274  0.206531
# 54      Eve Charge  0.241916  0.431233
# 55      Night Mins -0.105272  0.562286
# 56     Night Calls -0.788214  0.735034
# 57    Night Charge  1.190481  0.578185
# 58       Intl Mins -1.857890  0.029463
# 59      Intl Calls -0.085863  0.238753
# 60     Intl Charge -0.622193  0.324741
# 61  CustServ Calls  0.839831  0.839604
# 62          Churn?  0.570857  0.642823
